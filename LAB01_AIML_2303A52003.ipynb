# %% [markdown]
# <a href="https://colab.research.google.com/github/2303A52003/AIML_2303A52003/blob/main/LAB01_AIML_2303A52003.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# LAB01 - PYTHON LIBRARIES AND PACKAGES using numpy pandas
# 1.LIST
# 2.ARRAY
# 3.TYPE
# 4.Perform mathematical operations on these datasets created - multiplication, division, poweroff
# 5.Combine text with Numpy fuction to generate a textual output - ”Addition of Two: array1 +array 2
# 6. Implement np.sin(), log(), log2(), np.exp())

# %%
import numpy as np
lst1=[2,4,6]
array1 = np.array(lst1)
array1
# Out:
# array([2, 4, 6])

# %%
type(lst1)
# Out:
# list

# %%
type(array1)

# %%
import numpy as np
lst2 =[6,8,7]
array2 = np.array(lst2)
array2
# Out:
# array([6, 8, 7])

# %%
print("array2 multiplied by array1: ",array1*array2)
print("array2 divided by array1: ",array2/array1)
print("array2 raised to the power of array1: ",array2**array1)
# Out:
# array2 multiplied by array1:  [12 32 42]
# array2 divided by array1:  [3.         2.         1.16666667]
# array2 raised to the power of array1:  [    36   4096 117649]

# %%
 #sine function
print("Sine: ",np.sin(array1))
# logarithm
print("Natural logarithm: ",np.log(array1))
print("Base-10 logarithm: ",np.log10(array1))
print("Base-2 logarithm: ",np.log2(array1))
# Exponential
print("Exponential: ",np.exp(array1))
# Out:
# Sine:  [ 0.90929743 -0.7568025  -0.2794155 ]
# Natural logarithm:  [0.69314718 1.38629436 1.79175947]
# Base-10 logarithm:  [0.30103    0.60205999 0.77815125]
# Base-2 logarithm:  [1.        2.        2.5849625]
# Exponential:  [  7.3890561   54.59815003 403.42879349]

# %%
list2=[3,2,1]
array2=np.array(list2)
array2
# Out:
# array([3, 2, 1])

# %%
print("Adding two numpy arrays {array1} and {array2} together:", array1+array2)
# Out:
# Adding two numpy arrays {array1} and {array2} together: [5 6 7]

# %%
print(f"Adding two numpy arrays {array1} and {array2} together: {array1+array2}")
# Out:
# Adding two numpy arrays [2 4 6] and [3 2 1] together: [5 6 7]

# %% [markdown]
# part-02
# VISUALISATION OF DATA USING matplotlib, pyplots packages.
# 1. Generate a Data set for Health Care using the following:
# people = [’kiran’, arun’, ’vijay’, ’varun’]
# age =[25, 30, 35, 40, 45]
# height =[145, 151, 165, 173]
# weight=[45, 55, 65, 75]
# 2. Using the generated dataset given above. Generate the following graphs and justify the
# relationships among the vectors.
# 3. Scatter Plot
# 4. Bar Chart
# 5. Histogram
# 6. Provide Graph Title, labels for X, Y axis with proper justification and explanation of
# the graph.

# %%
 people = ['kiran', 'arun', 'vijay', 'varun']
 age =[25, 30, 35, 40, 45]
 height =[145, 151, 165, 173]
 weight=[45, 55, 65, 75]

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(weight, height)
plt.title("Relationship between Weight and Height of Patients")
plt.ylabel("Height in Meters")
plt.xlabel("Weight of Patients in Kgs")
plt.show()

# %% [markdown]
# bar plot

# %%
plt.figure(figsize=(12,4))
plt.title("People's weight in kgs",fontsize=14,
          fontstyle='italic')

# Main plot function 'bar'
plt.bar(x=people,height=weight, width=0.6,
        color='blue',edgecolor='k',alpha=0.6)

plt.xlabel("People",fontsize=15)
plt.xticks(fontsize=14,rotation=60)
plt.yticks(fontsize=14)
plt.ylabel("Weight (in kgs)",fontsize=15)
plt.show()

# %% [markdown]
# histogram plot

# %%
import numpy as np
plt.figure(figsize=(7,5))

# Main plot function 'hist'
plt.hist(weight,color='red',edgecolor='k', alpha=0.75,bins=5)

plt.title("Histogram of patient weight",fontsize=18)
plt.xlabel("Weight in kgs",fontsize=15)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.show()

# %% [markdown]
# PART-03 ACCESS DATA FROM VARIOUS SOURCES AND FORMATES.

# %%
import numpy as np
import pandas as pd

# %%
df1 = pd.read_table("vrindha.tsv")
df1
# Out:
#         f1       f2     f3
# 0  vrindha  likhith  surya

# %%
data2 = pd.read_csv("HistoricalPrices.csv")
data2
# Out:
#         Date      Open      High       Low     Close
# 0   08/07/24  39230.09  39477.96  38731.51  38763.45
# 1   08/06/24  38736.22  39449.53  38638.30  38997.66
# 2   08/05/24  39056.19  39056.19  38499.27  38703.27
# 3   08/02/24  40075.33  40075.33  39358.68  39737.26
# 4   08/01/24  40916.96  41096.66  40098.57  40347.97
# ..       ...       ...       ...       ...       ...
# 56  05/16/24  39912.34  40051.05  39864.68  39869.38
# 57  05/15/24  39615.10  39935.04  39615.10  39908.00
# 58  05/14/24  39466.76  39616.41  39371.92  39558.11
# 59  05/13/24  39591.28  39647.39  39403.05  39431.51
# 60  05/10/24  39466.52  39579.88  39406.26  39512.84
#
# [61 rows x 5 columns]

# %%
data3 = pd.read_excel("file_example_XLSX_10.xlsx")
data3
# Out:
#    0 First Name  Last Name  Gender        Country  Age        Date    Id
# 0  1      Dulce      Abril  Female  United States   32  15/10/2017  1562
# 1  2       Mara  Hashimoto  Female  Great Britain   25  16/08/2016  1582
# 2  3     Philip       Gent    Male         France   36  21/05/2015  2587
# 3  4   Kathleen     Hanner  Female  United States   25  15/10/2017  3549
# 4  5    Nereida    Magwood  Female  United States   58  16/08/2016  2468
# 5  6     Gaston      Brumm    Male  United States   24  21/05/2015  2554
# 6  7       Etta       Hurn  Female  Great Britain   56  15/10/2017  3598
# 7  8    Earlean     Melgar  Female  United States   27  16/08/2016  2456
# 8  9   Vincenza    Weiland  Female  United States   40  21/05/2015  6548
